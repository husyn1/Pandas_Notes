# %% [markdown]
# ## Indexes

# %% [markdown]
# ###### this notebook will explain what is an index and how to do some functions( searching index, changing index etc)

# %%
import pandas as pd

# %%
customers = {
    "firstname":["Sam","Tom","Phil"],
    "lastname":["johnson","Denis","Alli"],
    "email":["SamJ123@gmail.com","Tom_Den65@yahoo.com","Phil_Alli202@gmail.com"]
}


customers_df=pd.DataFrame(customers)
customers_df
#  the first column with numbers and no column name is called the index
# Out:
#   firstname lastname                   email
# 0       Sam  johnson       SamJ123@gmail.com
# 1       Tom    Denis     Tom_Den65@yahoo.com
# 2      Phil     Alli  Phil_Alli202@gmail.com

# %%
customers_df.email
# Out:
# 0         SamJ123@gmail.com
# 1       Tom_Den65@yahoo.com
# 2    Phil_Alli202@gmail.com
# Name: email, dtype: object

# %%
#  change the index
customers_df.set_index("email",inplace=True) 
# inplace = False is used to display the change but does not change the actual dataframe

# %%
customers_df
# Out:
#                        firstname lastname
# email
# SamJ123@gmail.com            Sam  johnson
# Tom_Den65@yahoo.com          Tom    Denis
# Phil_Alli202@gmail.com      Phil     Alli

# %%
# if u want to reset your index back to the default
customers_df.reset_index(inplace=True)

# %%
customers_df
# Out:
#                     email firstname lastname
# 0       SamJ123@gmail.com       Sam  johnson
# 1     Tom_Den65@yahoo.com       Tom    Denis
# 2  Phil_Alli202@gmail.com      Phil     Alli

# %% [markdown]
# #### Now using the stackoverlfow data

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col="Respondent")
schema_df = pd.read_csv("data/survey_results_schema.csv",index_col="Column")

# %%
df.head(4)
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes   NaN         13  Monthly
# 2           I am a developer by profession       No   NaN         19      NaN
# 3              I code primarily as a hobby      Yes   NaN         15      NaN
# 4           I am a developer by profession      Yes  25.0         18      NaN
#
#             CompTotal  ConvertedComp             Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN             Germany   European Euro
# 2                 NaN            NaN      United Kingdom  Pound sterling
# 3                 NaN            NaN  Russian Federation             NaN
# 4                 NaN            NaN             Albania    Albanian lek
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 1                     EUR  ...  Neither easy nor difficult
# ...

# %%
# lets change the index to the MainBranch column as it already has an id
df.set_index("MainBranch",inplace=True)

# %%
# now the MainBranch will be the index
df.head(5)
# Out:
#                                                    Hobbyist   Age Age1stCode  \
# MainBranch
# I am a developer by profession                          Yes   NaN         13
# I am a developer by profession                           No   NaN         19
# I code primarily as a hobby                             Yes   NaN         15
# I am a developer by profession                          Yes  25.0         18
# I used to be a developer by profession, but no ...      Yes  31.0         16
#
#                                                    CompFreq  CompTotal  \
# MainBranch
# I am a developer by profession                      Monthly        NaN
# I am a developer by profession                          NaN        NaN
# I code primarily as a hobby                             NaN        NaN
# I am a developer by profession                          NaN        NaN
# I used to be a developer by profession, but no ...      NaN        NaN
#
# ...

# %%
# resets the index to the default index
df.reset_index(inplace=True)

# %%
df
# Out:
#                                               MainBranch Hobbyist   Age  \
# 0                         I am a developer by profession      Yes   NaN
# 1                         I am a developer by profession       No   NaN
# 2                            I code primarily as a hobby      Yes   NaN
# 3                         I am a developer by profession      Yes  25.0
# 4      I used to be a developer by profession, but no...      Yes  31.0
# ...                                                  ...      ...   ...
# 64456                                                NaN      Yes   NaN
# 64457                                                NaN      Yes   NaN
# 64458                                                NaN      Yes   NaN
# 64459                                                NaN      Yes   NaN
# 64460                                                NaN      Yes   NaN
#
#       Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# ...

# %%
schema_df.head(10)
# Out:
#                                                     QuestionText
# Column
# Respondent     Randomized respondent ID number (not in order ...
# MainBranch     Which of the following options best describes ...
# Hobbyist                                 Do you code as a hobby?
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# CompFreq        Is that compensation weekly, monthly, or yearly?
# CompTotal      What is your current total compensation (salar...
# ConvertedComp  Salary converted to annual USD salaries using ...
# Country                                       Where do you live?
# CurrencyDesc   Which currency do you use day-to-day? If your ...

# %%
schema_df.loc['Age1stCode',"QuestionText"] #gives the whole value
# Out:
# 'At what age did you write your first line of code or program? (e.g., webpage, Hello World, Scratch project)'

# %%
# an easier way to do it
schema_df.sort_index(inplace=True) # gets index in alphbetical order (ascending order)
               
# schema_df.sort_index(ascending=False) sorts the index in descending order

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# CompFreq             Is that compensation weekly, monthly, or yearly?
# CompTotal           What is your current total compensation (salar...
# ConvertedComp       Salary converted to annual USD salaries using ...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]
